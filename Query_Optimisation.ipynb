# %% [markdown]
# <a href="https://colab.research.google.com/github/Coreyy989/Northstar-databases-analytics/blob/main/Query_Optimisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MongoDB indexing and explain plans")
# Out:
# MongoDB indexing and explain plans
