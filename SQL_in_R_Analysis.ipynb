# %% [markdown]
# <a href="https://colab.research.google.com/github/Coreyy989/Northstar-databases-analytics/blob/main/SQL_in_R_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SQL in R analysis for NorthStar dataset")
# Out:
# SQL in R analysis for NorthStar dataset

# %%
# Load R support in Google Colab

# %load_ext rpy2.ipython

# %%
# %%R
#
# print("R environment loaded successfully")
# Out:
# [1] "R environment loaded successfully"

# %%
# %%R
#
# # Create a sample deliveries table
#
# delivery_data <- data.frame(
#   delivery_id = c("D001", "D002", "D003"),
#   delivery_status = c("Delayed", "Completed", "Failed"),
#   hub_id = c("H01", "H02", "H03")
# )
#
# print(delivery_data)
# Out:
#   delivery_id delivery_status hub_id
# 1        D001         Delayed    H01
# 2        D002       Completed    H02
# 3        D003          Failed    H03

# %%
# %%R
#
# # Simulated SQL query example
#
# print("SELECT * FROM deliveries WHERE delivery_status = 'Delayed'")
# Out:
# [1] "SELECT * FROM deliveries WHERE delivery_status = 'Delayed'"

# %%
# %%R
#
# # Count delivery outcomes
#
# table(delivery_data$delivery_status)
# Out:
# Completed   Delayed    Failed
#         1         1         1
